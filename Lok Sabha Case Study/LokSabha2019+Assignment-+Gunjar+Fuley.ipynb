# %%
import numpy as np
import pandas as pd
ls = pd.read_csv("C:\\Users\\ANIL FULE\\Desktop\\Lok+Sabha_2019.csv")
print(ls)
# Out:
#       Unnamed: 0          STATE     CONSTITUENCY                    NAME  \
# 0              0      Telangana         ADILABAD          SOYAM BAPU RAO
# 1              1      Telangana         ADILABAD            Godam Nagesh
# 2              2      Telangana         ADILABAD           RATHOD RAMESH
# 3              4  Uttar Pradesh             AGRA   Satyapal Singh Baghel
# 4              5  Uttar Pradesh             AGRA        Manoj Kumar Soni
# ...          ...            ...              ...                     ...
# 2013        2257    Maharashtra  YAVATMAL-WASHIM  Vaishali Sudhakar Yede
# 2014        2258    Maharashtra  YAVATMAL-WASHIM      Anil Jayram Rathod
# 2015        2259      Telangana        ZAHIRABAD               B.B.PATIL
# 2016        2260      Telangana        ZAHIRABAD         MADAN MOHAN RAO
# 2017        2261      Telangana        ZAHIRABAD      BANALA LAXMA REDDY
#
#       WINNER  PARTY    SYMBOL  GENDER  CRIMINAL CASES  AGE CATEGORY  \
# ...

# %%
ls['SYMBOL'].unique()
# Out:
# array(['Lotus', 'Car', 'Hand', 'Elephant', 'Clock', 'Cup & Saucer',
#        'Coat', 'Hammer, Sickle and Star', 'Pot', 'Flowers and Grass',
#        'Spade & Stoker', 'Bicycle', 'Ears of Corn And Sickle',
#        'Ceiling Fan', 'Glass Tumbler', 'Spectacles', 'Walking Stick',
#        'Spanner', 'Bow and Arrow', 'Whistle', 'Broom', 'Scales', 'Plough',
#        'Ink Pot & Pen', 'Apple', 'Table', 'Helicopter', 'Rising Sun',
#        'Mango', 'Gift Pack', 'Ganna Kisan', 'Battery Torch', 'Two Leaves',
#        'Hurricane Lamp', 'Flag with Three Stars', 'Football', 'Saw',
#        'Bangles', 'Maize', 'A lady farmer carrying paddy on her head',
#        'Book', 'Cot', 'Conch', 'Kite', 'Telephone',
#        'Tractor Chalata Kisan', 'Air Conditioner', 'CHESS BOARD',
#        'Almirah', 'Balloon', 'Hand Pump', 'Bead Necklace',
#        'Auto- Rickshaw', 'Gas Cylinder', 'DIAMOND', 'Key', 'Arrow',
#        'FLUTE', 'Baby Walker', 'Black Board', 'Lion', 'Lock and Key',
# ...

# %%
ls['EDUCATION'].unique()
# Out:
# array(['12th Pass', 'Post Graduate', 'Doctorate', 'Graduate', 'Others',
#        '10th Pass', '8th Pass', 'Graduate Professional', 'Literate',
#        'Illiterate', '5th Pass', 'Not Available'], dtype=object)

# %%
ls['EDUCATION'].value_counts()
# Out:
# Post Graduate            503
# Graduate                 441
# Graduate Professional    336
# 12th Pass                256
# 10th Pass                196
# 8th Pass                  78
# Doctorate                 73
# Others                    50
# Literate                  30
# 5th Pass                  28
# Not Available             22
# Illiterate                 5
# Name: EDUCATION, dtype: int64

# %%
ls['PARTY'].unique()
# Out:
# array(['BJP', 'TRS', 'INC', 'BSP', 'NCP', 'VBA', 'APoI', 'CPI(M)', 'BDJS',
#        'AITC', 'RSP', 'SP', 'YSRCP', 'TDP', 'JnP', 'INLD', 'SBSP', 'IND',
#        'SHS', 'AAP', 'SAD', 'JKN', 'JKPDP', 'JPC', 'DMK', 'PMK', 'NTK',
#        'MNM', 'AIADMK', 'RJD', 'CPI(ML)(L)', 'SSD', 'PPA', 'JD(S)',
#        'NPEP', 'BMUP', 'BJD', 'AIMIM', 'HAMS', 'AHFBK', 'PPID', 'SPL',
#        'ASDC', 'RLD', 'PSPL', 'JD(U)', 'BTP', 'AIFB', 'AGP', 'AIUDF',
#        'ABSKP', 'PUNEKP', 'RTORP', 'JNJP', 'LTSP', 'RVNP', 'JANADIP',
#        'SDPI', 'DMDK', 'ABGP', 'VCK', 'JMM', 'LIP', 'JDR', 'MOSP', 'MADP',
#        'AJPR', 'PMP', 'BBMP', 'AJSUP', 'JVM', 'RMPOI', 'LJP', 'BJKVP',
#        'SWP', 'NEINDP', 'RSPSR', 'ravp', 'RSOSP', 'BLSP', 'WPOI',
#        'SUCI(C)', 'SJDD', 'ANC', 'JDL', 'VSIP', 'AAM', 'JKP', 'BOPF',
#        'UPPL', 'CPIM', 'GGP', 'KEC(M)', 'KEC', 'JAPL', 'AKBMP', 'TJS',
#        'IUML', 'BSCP', 'ADAL', 'BRPI', 'MNF', 'PRISMP', 'VPI', 'YKP',
# ...

# %%
ls.mean()
# Out:
# Unnamed: 0                                 1.134744e+03
# WINNER                                     2.670961e-01
# CRIMINAL CASES                             1.469940e+00
# AGE                                        5.227354e+01
# ASSETS                                     1.331019e+08
# LIABILITIES                                1.995616e+07
# GENERAL VOTES                              2.911903e+05
# POSTAL VOTES                               1.105111e+03
# TOTAL VOTES                                2.922954e+05
# OVER TOTAL ELECTORS IN CONSTITUENCY        1.759681e+01
# OVER TOTAL VOTES POLLED IN CONSTITUENCY    2.580849e+01
# TOTAL ELECTORS                             1.660261e+06
# dtype: float64

# %%
ls.columns
# Out:
# Index(['Unnamed: 0', 'STATE', 'CONSTITUENCY', 'NAME', 'WINNER', 'PARTY',
#        'SYMBOL', 'GENDER', 'CRIMINAL CASES', 'AGE', 'CATEGORY', 'EDUCATION',
#        'ASSETS', 'LIABILITIES', 'GENERAL VOTES', 'POSTAL VOTES', 'TOTAL VOTES',
#        'OVER TOTAL ELECTORS IN CONSTITUENCY',
#        'OVER TOTAL VOTES POLLED IN CONSTITUENCY', 'TOTAL ELECTORS'],
#       dtype='object')

# %%
winners = ls[ls['WINNER']!=0]
winners
# Out:
#       Unnamed: 0          STATE     CONSTITUENCY  \
# 0              0      Telangana         ADILABAD
# 3              4  Uttar Pradesh             AGRA
# 6              7    Maharashtra       AHMADNAGAR
# 9             10        Gujarat   AHMEDABAD EAST
# 11            12        Gujarat   AHMEDABAD WEST
# ...          ...            ...              ...
# 1999        2243    Maharashtra           WARDHA
# 2003        2247         Kerala          WAYANAD
# 2006        2250   NCT OF Delhi       WEST DELHI
# 2009        2253    Maharashtra  YAVATMAL-WASHIM
# 2015        2259      Telangana        ZAHIRABAD
#
#                                    NAME  WINNER PARTY         SYMBOL  GENDER  \
# 0                        SOYAM BAPU RAO       1   BJP          Lotus    MALE
# 3                 Satyapal Singh Baghel       1   BJP          Lotus    MALE
# 6     Dr. SUJAY RADHAKRISHNA VIKHEPATIL       1   BJP          Lotus    MALE
# ...

# %%
winners['PARTY'].unique()
# Out:
# array(['BJP', 'CPI(M)', 'INC', 'YSRCP', 'BSP', 'IND', 'JKN', 'DMK',
#        'AITC', 'BJD', 'AIMIM', 'SP', 'JD(U)', 'NCP', 'SAD', 'SHS', 'TRS',
#        'VCK', 'AIUDF', 'AJSUP', 'TDP', 'LJP', 'JD(S)', 'RSP', 'KEC(M)',
#        'IUML', 'ADAL', 'MNF', 'NDPP', 'RLTP', 'NPF', 'JMM', 'AAP', 'SKM',
#        'AIADMK', 'NPEP'], dtype=object)

# %%
winners['PARTY'].value_counts()
# Out:
# BJP       300
# INC        52
# DMK        23
# YSRCP      22
# AITC       22
# SHS        18
# JD(U)      16
# BJD        11
# BSP        11
# TRS         9
# LJP         6
# CPI(M)      5
# NCP         5
# SP          5
# IND         4
# TDP         3
# JKN         3
# IUML        3
# AIMIM       2
# ADAL        2
# SAD         2
# AJSUP       1
# NDPP        1
# AAP         1
# NPF         1
# AIADMK      1
# AIUDF       1
# SKM         1
# NPEP        1
# JMM         1
# RLTP        1
# VCK         1
# MNF         1
# JD(S)       1
# RSP         1
# KEC(M)      1
# Name: PARTY, dtype: int64

# %%
winners['PARTY'].head(n=5)
# Out:
# 0     BJP
# 3     BJP
# 6     BJP
# 9     BJP
# 11    BJP
# Name: PARTY, dtype: object

# %%
new = winners['PARTY'].value_counts()
new
# Out:
# BJP       300
# INC        52
# DMK        23
# YSRCP      22
# AITC       22
# SHS        18
# JD(U)      16
# BJD        11
# BSP        11
# TRS         9
# LJP         6
# CPI(M)      5
# NCP         5
# SP          5
# IND         4
# TDP         3
# JKN         3
# IUML        3
# AIMIM       2
# ADAL        2
# SAD         2
# AJSUP       1
# NDPP        1
# AAP         1
# NPF         1
# AIADMK      1
# AIUDF       1
# SKM         1
# NPEP        1
# JMM         1
# RLTP        1
# VCK         1
# MNF         1
# JD(S)       1
# RSP         1
# KEC(M)      1
# Name: PARTY, dtype: int64

# %%
new.head(n=5)
# Out:
# BJP      300
# INC       52
# DMK       23
# YSRCP     22
# AITC      22
# Name: PARTY, dtype: int64

# %%
BJPr = ls[ls['PARTY'] == 'BJP']
BJPr
# Out:
#       Unnamed: 0           STATE    CONSTITUENCY  \
# 0              0       Telangana        ADILABAD
# 3              4   Uttar Pradesh            AGRA
# 6              7     Maharashtra      AHMADNAGAR
# 9             10         Gujarat  AHMEDABAD EAST
# 11            12         Gujarat  AHMEDABAD WEST
# ...          ...             ...             ...
# 1988        2229  Andhra Pradesh   VISAKHAPATNAM
# 1996        2239       Telangana        WARANGAL
# 1999        2243     Maharashtra          WARDHA
# 2006        2250    NCT OF Delhi      WEST DELHI
# 2017        2261       Telangana       ZAHIRABAD
#
#                                    NAME  WINNER PARTY SYMBOL  GENDER  \
# 0                        SOYAM BAPU RAO       1   BJP  Lotus    MALE
# 3                 Satyapal Singh Baghel       1   BJP  Lotus    MALE
# 6     Dr. SUJAY RADHAKRISHNA VIKHEPATIL       1   BJP  Lotus    MALE
# 9            Patel Hasmukhbhai Somabhai       1   BJP  Lotus    MALE
# ...

# %%
BJPrm = BJPr[BJPr['GENDER'] == 'MALE']
BJPrm
# Out:
#       Unnamed: 0           STATE    CONSTITUENCY  \
# 0              0       Telangana        ADILABAD
# 3              4   Uttar Pradesh            AGRA
# 6              7     Maharashtra      AHMADNAGAR
# 9             10         Gujarat  AHMEDABAD EAST
# 11            12         Gujarat  AHMEDABAD WEST
# ...          ...             ...             ...
# 1972        2211  Andhra Pradesh      VIJAYAWADA
# 1996        2239       Telangana        WARANGAL
# 1999        2243     Maharashtra          WARDHA
# 2006        2250    NCT OF Delhi      WEST DELHI
# 2017        2261       Telangana       ZAHIRABAD
#
#                                    NAME  WINNER PARTY SYMBOL GENDER  \
# 0                        SOYAM BAPU RAO       1   BJP  Lotus   MALE
# 3                 Satyapal Singh Baghel       1   BJP  Lotus   MALE
# 6     Dr. SUJAY RADHAKRISHNA VIKHEPATIL       1   BJP  Lotus   MALE
# 9            Patel Hasmukhbhai Somabhai       1   BJP  Lotus   MALE
# ...

# %%
BJPmf = BJPr['GENDER'].value_counts()
BJPmf
# Out:
# MALE      366
# FEMALE     54
# Name: GENDER, dtype: int64

# %%
INCr = ls[ls['PARTY'] == 'INC']
INCmf = INCr['GENDER'].value_counts()
INCmf
# Out:
# MALE      359
# FEMALE     54
# Name: GENDER, dtype: int64

# %%
DMKr = ls[ls['PARTY'] == 'DMK']
DMKmf = DMKr['GENDER'].value_counts()
DMKmf
# Out:
# MALE      21
# FEMALE     2
# Name: GENDER, dtype: int64

# %%
YSRCPr = ls[ls['PARTY'] == 'YSRCP']
YSRCPmf = YSRCPr['GENDER'].value_counts()
YSRCPmf
# Out:
# MALE      21
# FEMALE     4
# Name: GENDER, dtype: int64

# %%
AITCr = ls[ls['PARTY'] == 'AITC']
AITCmf = AITCr['GENDER'].value_counts()
AITCmf
# Out:
# MALE      28
# FEMALE    19
# Name: GENDER, dtype: int64

# %%
BJPc = BJPr['CATEGORY'].value_counts()
BJPc
# Out:
# GENERAL    304
# SC          62
# ST          54
# Name: CATEGORY, dtype: int64

# %%
INCc = INCr['CATEGORY'].value_counts()
INCc
# Out:
# GENERAL    291
# SC          73
# ST          49
# Name: CATEGORY, dtype: int64

# %%
DMKc = DMKr['CATEGORY'].value_counts()
DMKc
# Out:
# GENERAL    19
# SC          4
# Name: CATEGORY, dtype: int64

# %%
YSRCPc = YSRCPr['CATEGORY'].value_counts()
YSRCPc
# Out:
# GENERAL    20
# SC          4
# ST          1
# Name: CATEGORY, dtype: int64

# %%
AITCc = AITCr['CATEGORY'].value_counts()
AITCc
# Out:
# GENERAL    32
# SC         10
# ST          5
# Name: CATEGORY, dtype: int64

# %%
BJPAVG = BJPr['AGE'].mean()
BJPAVG
# Out:
# 54.04255319148936

# %%
INCAVG = INCr['AGE'].mean()
INCAVG
# Out:
# 55.03147699757869

# %%
DMKAVG = DMKr['AGE'].mean()
DMKAVG
# Out:
# 55.82608695652174

# %%
YSRCPAVG = YSRCPr['AGE'].mean()
YSRCPAVG
# Out:
# 50.32

# %%
AITCAVG = AITCr['AGE'].mean()
AITCAVG
# Out:
# 54.04255319148936

# %%
cons = ls['STATE'].value_counts()
cons
# Out:
# Uttar Pradesh                251
# Bihar                        218
# Tamil Nadu                   189
# Maharashtra                  175
# West Bengal                  173
# Andhra Pradesh               101
# Madhya Pradesh                93
# Rajasthan                     74
# Telangana                     74
# Odisha                        73
# Karnataka                     72
# Gujarat                       69
# Jharkhand                     65
# Kerala                        63
# Punjab                        53
# Assam                         44
# Haryana                       41
# Chhattisgarh                  38
# Jammu & Kashmir               28
# NCT OF Delhi                  24
# Uttarakhand                   14
# Manipur                       10
# Arunachal Pradesh             10
# Himachal Pradesh               9
# Tripura                        8
# Goa                            6
# Dadra & Nagar Haveli           6
# Meghalaya                      6
# ...

# %%
cons.head(n=5)
# Out:
# Uttar Pradesh    251
# Bihar            218
# Tamil Nadu       189
# Maharashtra      175
# West Bengal      173
# Name: STATE, dtype: int64

# %%
UPc = ls[ls['STATE'] == 'Uttar Pradesh']
UPAVG = UPc['CRIMINAL CASES'].mean()
UPAVG
# Out:
# 1.7408906882591093

# %%
BRc = ls[ls['STATE'] == 'Bihar']
BRAVG = BRc['CRIMINAL CASES'].mean()
BRAVG
# Out:
# 1.471698113207547

# %%
TNc = ls[ls['STATE'] == 'Tamil Nadu']
TNAVG = TNc['CRIMINAL CASES'].mean()
TNAVG
# Out:
# 0.8846153846153846

# %%
MHc = ls[ls['STATE'] == 'Maharashtra']
MHAVG = MHc['CRIMINAL CASES'].mean()
MHAVG
# Out:
# 1.7257142857142858

# %%
WBc = ls[ls['STATE'] == 'West Bengal']
WBAVG = WBc['CRIMINAL CASES'].mean()
WBAVG
# Out:
# 1.7514450867052023

# %%
UPAS = UPc['ASSETS'].mean()
UPAS
# Out:
# 152778869.1214575

# %%
BRAS = BRc['ASSETS'].mean()
BRAS
# Out:
# 69936017.31132075

# %%
TNAS = TNc['ASSETS'].mean()
TNAS
# Out:
# 139050747.15384614

# %%
MHAS = MHc['ASSETS'].mean()
MHAS
# Out:
# 146162190.62285715

# %%
WBAS = WBc['ASSETS'].mean()
WBAS
# Out:
# 26840526.57803468

# %%
WINAVG = winners['ASSETS'].mean()
WINAVG
# Out:
# 209135673.3005566

# %%
losers = ls[ls['WINNER']!=1]
losers
# Out:
#       Unnamed: 0          STATE     CONSTITUENCY                     NAME  \
# 1              1      Telangana         ADILABAD             Godam Nagesh
# 2              2      Telangana         ADILABAD            RATHOD RAMESH
# 4              5  Uttar Pradesh             AGRA         Manoj Kumar Soni
# 5              6  Uttar Pradesh             AGRA             Preeta Harit
# 7              8    Maharashtra       AHMADNAGAR  SANGRAM ARUNKAKA JAGTAP
# ...          ...            ...              ...                      ...
# 2012        2256    Maharashtra  YAVATMAL-WASHIM   Parashram Bhaosing Ade
# 2013        2257    Maharashtra  YAVATMAL-WASHIM   Vaishali Sudhakar Yede
# 2014        2258    Maharashtra  YAVATMAL-WASHIM       Anil Jayram Rathod
# 2016        2260      Telangana        ZAHIRABAD          MADAN MOHAN RAO
# 2017        2261      Telangana        ZAHIRABAD       BANALA LAXMA REDDY
#
#       WINNER  PARTY                 SYMBOL  GENDER  CRIMINAL CASES  AGE  \
# ...

# %%
LOSAVG = losers['ASSETS'].mean()
LOSAVG
# Out:
# 104954788.82005495

# %%
r1 = WINAVG/LOSAVG
print(r1)
# Out:
# 1.9926263074962671

# %%
WINAVG1 = winners['CRIMINAL CASES'].mean()
WINAVG1
# Out:
# 1.9090909090909092

# %%
LOSAVG1 = losers['CRIMINAL CASES'].mean()
LOSAVG1
# Out:
# 1.307481125600549

# %%
r2 = WINAVG1/LOSAVG1
print(r2)
# Out:
# 1.4601288475304226

# %%
WINMALE = winners[(winners['GENDER'] == 'MALE')]
WINMALE
# Out:
#       Unnamed: 0          STATE    CONSTITUENCY  \
# 0              0      Telangana        ADILABAD
# 3              4  Uttar Pradesh            AGRA
# 6              7    Maharashtra      AHMADNAGAR
# 9             10        Gujarat  AHMEDABAD EAST
# 11            12        Gujarat  AHMEDABAD WEST
# ...          ...            ...             ...
# 1994        2237      Telangana        WARANGAL
# 1999        2243    Maharashtra          WARDHA
# 2003        2247         Kerala         WAYANAD
# 2006        2250   NCT OF Delhi      WEST DELHI
# 2015        2259      Telangana       ZAHIRABAD
#
#                                    NAME  WINNER PARTY SYMBOL GENDER  \
# 0                        SOYAM BAPU RAO       1   BJP  Lotus   MALE
# 3                 Satyapal Singh Baghel       1   BJP  Lotus   MALE
# 6     Dr. SUJAY RADHAKRISHNA VIKHEPATIL       1   BJP  Lotus   MALE
# 9            Patel Hasmukhbhai Somabhai       1   BJP  Lotus   MALE
# ...

# %%
tmale = WINMALE['GENDER'].value_counts()
tmale
# Out:
# MALE    463
# Name: GENDER, dtype: int64

# %%
WINFEMALE = winners[(winners['GENDER'] != 'MALE')]
WINFEMALE
# Out:
#       Unnamed: 0           STATE       CONSTITUENCY  \
# 27            29          Kerala            ALATHUR
# 37            40   Uttar Pradesh          ALLAHABAD
# 47            51  Andhra Pradesh         AMALAPURAM
# 57            63   Uttar Pradesh             AMETHI
# 59            65     Maharashtra           AMRAVATI
# ...          ...             ...                ...
# 1920        2154       Karnataka  UDUPI CHIKMAGALUR
# 1933        2168     West Bengal           ULUBERIA
# 1945        2181         Gujarat           VADODARA
# 1947        2184           Bihar           VAISHALI
# 2009        2253     Maharashtra    YAVATMAL-WASHIM
#
#                                       NAME  WINNER  PARTY             SYMBOL  \
# 27                           RAMYA HARIDAS       1    INC               Hand
# 37                     Rita Bahuguna Joshi       1    BJP              Lotus
# 47                         CHINTA ANURADHA       1  YSRCP        Ceiling Fan
# ...

# %%
tfemale = WINFEMALE['GENDER'].value_counts()
tfemale
# Out:
# FEMALE    76
# Name: GENDER, dtype: int64

# %%
LOSMALE1 = losers[(losers['GENDER'] == 'MALE')]
LOSMALE1
# Out:
#       Unnamed: 0          STATE     CONSTITUENCY                     NAME  \
# 1              1      Telangana         ADILABAD             Godam Nagesh
# 2              2      Telangana         ADILABAD            RATHOD RAMESH
# 4              5  Uttar Pradesh             AGRA         Manoj Kumar Soni
# 7              8    Maharashtra       AHMADNAGAR  SANGRAM ARUNKAKA JAGTAP
# 8              9    Maharashtra       AHMADNAGAR    SUDHAKAR LAXMAN AVHAD
# ...          ...            ...              ...                      ...
# 2011        2255    Maharashtra  YAVATMAL-WASHIM      Pravin Govind Pawar
# 2012        2256    Maharashtra  YAVATMAL-WASHIM   Parashram Bhaosing Ade
# 2014        2258    Maharashtra  YAVATMAL-WASHIM       Anil Jayram Rathod
# 2016        2260      Telangana        ZAHIRABAD          MADAN MOHAN RAO
# 2017        2261      Telangana        ZAHIRABAD       BANALA LAXMA REDDY
#
#       WINNER PARTY                 SYMBOL GENDER  CRIMINAL CASES  AGE  \
# ...

# %%
tmale1 = LOSMALE1['GENDER'].value_counts()
tmale1
# Out:
# MALE    1297
# Name: GENDER, dtype: int64

# %%
LOSFEMALE1 = losers[(losers['GENDER'] != 'MALE')]
LOSFEMALE1
# Out:
#       Unnamed: 0           STATE     CONSTITUENCY                    NAME  \
# 5              6   Uttar Pradesh             AGRA            Preeta Harit
# 10            11         Gujarat   AHMEDABAD EAST           Gitaben Patel
# 19            21   Uttar Pradesh         AKBARPUR            Nisha Sachan
# 25            27          Kerala        ALAPPUZHA     Adv. SHANIMOL OSMAN
# 35            37     West Bengal      ALIPURDUARS              MILI ORAON
# ...          ...             ...              ...                     ...
# 1988        2229  Andhra Pradesh    VISAKHAPATNAM  DAGGUBATI PURANDESWARI
# 1989        2231  Andhra Pradesh    VISAKHAPATNAM    PEDADA. RAMANIKUMARI
# 1997        2240       Telangana         WARANGAL     BUNGA JYOTHI RAMANA
# 2000        2244     Maharashtra           WARDHA     Charulata Rao Tokas
# 2013        2257     Maharashtra  YAVATMAL-WASHIM  Vaishali Sudhakar Yede
#
#       WINNER  PARTY          SYMBOL  GENDER  CRIMINAL CASES  AGE CATEGORY  \
# ...

# %%
tfemale1 = LOSFEMALE1['GENDER'].value_counts()
tfemale1
# Out:
# FEMALE    182
# Name: GENDER, dtype: int64

# %%
WINAVGAGE = winners['AGE'].mean()
WINAVGAGE
# Out:
# 54.44155844155844

# %%
LOSAVGAGE = losers['AGE'].mean()
LOSAVGAGE
# Out:
# 51.48343475321163

# %%
RATIOAVGAGE = WINAVGAGE/LOSAVGAGE
RATIOAVGAGE
# Out:
# 1.0574577765164022

# %%
varanasi = ls[ls['CONSTITUENCY'] == 'VARANASI']
varanasi
# Out:
#       Unnamed: 0          STATE CONSTITUENCY           NAME  WINNER PARTY  \
# 1963        2202  Uttar Pradesh     VARANASI  NARENDRA MODI       1   BJP
# 1964        2203  Uttar Pradesh     VARANASI  SHALINI YADAV       0    SP
# 1965        2204  Uttar Pradesh     VARANASI       AJAY RAI       0   INC
#
#        SYMBOL  GENDER  CRIMINAL CASES  AGE CATEGORY      EDUCATION  \
# 1963    Lotus    MALE             0.0   68  GENERAL  Post Graduate
# 1964  Bicycle  FEMALE             0.0   47  GENERAL       Graduate
# 1965     Hand    MALE             8.0   49  GENERAL       Graduate
#
#           ASSETS  LIABILITIES  GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 1963  25136119.0          0.0         673453          1211       674664
# 1964  12600000.0     788131.0         194763           396       195159
# 1965  13970015.0          0.0         152456            92       152548
#
#       OVER TOTAL ELECTORS IN CONSTITUENCY  \
# 1963                            36.334946
# ...

# %%
gandhinagar = ls[ls['CONSTITUENCY'] == 'GANDHINAGAR']
gandhinagar
# Out:
#      Unnamed: 0    STATE CONSTITUENCY              NAME  WINNER PARTY SYMBOL  \
# 660         746  Gujarat  GANDHINAGAR         AMIT SHAH       1   BJP  Lotus
# 661         747  Gujarat  GANDHINAGAR  Dr. C. J. CHAVDA       0   INC   Hand
#
#     GENDER  CRIMINAL CASES  AGE CATEGORY              EDUCATION       ASSETS  \
# 660   MALE             4.0   54  GENERAL              12th Pass  403275307.0
# 661   MALE             0.0   61  GENERAL  Graduate Professional  120468223.0
#
#      LIABILITIES  GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 660    4769587.0         889925          4699       894624
# 661   19223728.0         334082          3528       337610
#
#      OVER TOTAL ELECTORS IN CONSTITUENCY  \
# 660                            45.977843
# 661                            17.350954
#
#      OVER TOTAL VOTES POLLED IN CONSTITUENCY  TOTAL ELECTORS
# 660                                69.575821         1945772
# 661                                26.256274         1945772

# %%
gandhinagar['NAME']
# Out:
# 660           AMIT SHAH
# 661    Dr. C. J. CHAVDA
# Name: NAME, dtype: object

# %%
NM = varanasi[varanasi['NAME']=='NARENDRA MODI']
NM
# Out:
#       Unnamed: 0          STATE CONSTITUENCY           NAME  WINNER PARTY  \
# 1963        2202  Uttar Pradesh     VARANASI  NARENDRA MODI       1   BJP
#
#      SYMBOL GENDER  CRIMINAL CASES  AGE CATEGORY      EDUCATION      ASSETS  \
# 1963  Lotus   MALE             0.0   68  GENERAL  Post Graduate  25136119.0
#
#       LIABILITIES  GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 1963          0.0         673453          1211       674664
#
#       OVER TOTAL ELECTORS IN CONSTITUENCY  \
# 1963                            36.334946
#
#       OVER TOTAL VOTES POLLED IN CONSTITUENCY  TOTAL ELECTORS
# 1963                                63.597809         1856791

# %%
NMn = NM['OVER TOTAL VOTES POLLED IN CONSTITUENCY']
NMn
# Out:
# 1963    63.597809
# Name: OVER TOTAL VOTES POLLED IN CONSTITUENCY, dtype: float64

# %%
SY = varanasi[varanasi['NAME']=='SHALINI YADAV']
SY
# Out:
#       Unnamed: 0          STATE CONSTITUENCY           NAME  WINNER PARTY  \
# 1964        2203  Uttar Pradesh     VARANASI  SHALINI YADAV       0    SP
#
#        SYMBOL  GENDER  CRIMINAL CASES  AGE CATEGORY EDUCATION      ASSETS  \
# 1964  Bicycle  FEMALE             0.0   47  GENERAL  Graduate  12600000.0
#
#       LIABILITIES  GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 1964     788131.0         194763           396       195159
#
#       OVER TOTAL ELECTORS IN CONSTITUENCY  \
# 1964                            10.510553
#
#       OVER TOTAL VOTES POLLED IN CONSTITUENCY  TOTAL ELECTORS
# 1964                                18.396839         1856791

# %%
SYn = SY['OVER TOTAL VOTES POLLED IN CONSTITUENCY']
SYn
# Out:
# 1964    18.396839
# Name: OVER TOTAL VOTES POLLED IN CONSTITUENCY, dtype: float64

# %%
AR = varanasi[varanasi['NAME']=='AJAY RAI']
AR
# Out:
#       Unnamed: 0          STATE CONSTITUENCY      NAME  WINNER PARTY SYMBOL  \
# 1965        2204  Uttar Pradesh     VARANASI  AJAY RAI       0   INC   Hand
#
#      GENDER  CRIMINAL CASES  AGE CATEGORY EDUCATION      ASSETS  LIABILITIES  \
# 1965   MALE             8.0   49  GENERAL  Graduate  13970015.0          0.0
#
#       GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 1965         152456            92       152548
#
#       OVER TOTAL ELECTORS IN CONSTITUENCY  \
# 1965                              8.21568
#
#       OVER TOTAL VOTES POLLED IN CONSTITUENCY  TOTAL ELECTORS
# 1965                                14.380074         1856791

# %%
ARn = AR['OVER TOTAL VOTES POLLED IN CONSTITUENCY']
ARn
# Out:
# 1965    14.380074
# Name: OVER TOTAL VOTES POLLED IN CONSTITUENCY, dtype: float64

# %%
HIGH = max(ls['OVER TOTAL ELECTORS IN CONSTITUENCY'])
HIGH
# Out:
# 51.95101197

# %%
CAN = ls[ls['OVER TOTAL ELECTORS IN CONSTITUENCY'] == 51.95101197]
CAN
# Out:
#       Unnamed: 0   STATE CONSTITUENCY          NAME  WINNER PARTY SYMBOL  \
# 2003        2247  Kerala      WAYANAD  Rahul Gandhi       1   INC   Hand
#
#      GENDER  CRIMINAL CASES  AGE CATEGORY      EDUCATION       ASSETS  \
# 2003   MALE             5.0   48  GENERAL  Post Graduate  158877063.0
#
#       LIABILITIES  GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 2003    7201904.0         705034          1333       706367
#
#       OVER TOTAL ELECTORS IN CONSTITUENCY  \
# 2003                            51.951012
#
#       OVER TOTAL VOTES POLLED IN CONSTITUENCY  TOTAL ELECTORS
# 2003                                64.640694         1359679

# %%
sum1 = varanasi['OVER TOTAL VOTES POLLED IN CONSTITUENCY'].sum()
sum1
# Out:
# 96.37472203

# %%
over1 = (NM['OVER TOTAL VOTES POLLED IN CONSTITUENCY'] / sum1) * 100
over1
# Out:
# 1963    65.990135
# Name: OVER TOTAL VOTES POLLED IN CONSTITUENCY, dtype: float64
